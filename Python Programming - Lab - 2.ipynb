# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2101CS405</b></center>
# <center><b><h1>Lab - 2</b></center>
# <pre>

# %% [markdown]
# # if..else..

# %% [markdown]
# ### 01) WAP to check whether the given number is positive or negative.

# %%
a=int(input("enter no: "))
if(a>=0):
    print("number is positive.")
else:
    print("number is negative.")
# Out:
# enter no: -5
# number is negative.

# %% [markdown]
# ### 02) WAP to check whether the given number is odd or even

# %%
a=int(input("enter no:"))
if(a%2==0):
    print("number is even.")
else:
    print("number is odd.")
# Out:
# enter no:5
# number is odd.

# %% [markdown]
# ###  03) WAP to find out largest number from given two numbers using simple if and ternary operator.

# %%
a=int(input("Enter no:"))
b=int(input("Enter another no:"))

if a>b:
    print(a,"is largest")
else:
    print(b,"is largest")
print(a if a>b else b ,"is largest using ternary")
# Out:
# Enter no:5
# Enter another no:6
# 6 is largest
# 6 is largest using ternary

# %% [markdown]
# ### 04) WAP to find out largest number from given three numbers.

# %%
a=int(input("Enter no. a:"))
b=int(input("Enter no. b:"))
c=int(input("Enter no. c:"))

print(a if a>b and a>c else b if b>c else c, "is largest" )
# Out:
# Enter no. a:4
# Enter no. b:5
# Enter no. c:6
# 6 is largest
# 6 is largest

# %% [markdown]
#  05) WAP to check whether the given year is leap year or not.
# [If a year can be divisible by 4 but not divisible by 100 then it is leap year but if it is divisible by 400 then it is leap year]

# %%
a=int(input("Enter year:"))
if a%4==0 and a%100!=0 :
    print(a,"is leap year.")
elif a%400==0:
    print(a,"is leap year.")
else:
    print(a,"is not leap year.")
# Out:
# Enter year:2021
# 2021 is not leap year.

# %% [markdown]
# ### 06) WAP in python to display the name of the day according to the number given by the user

# %%
a=int(input("Enter no. :"))
if a==1:
    print("Monday")
elif a==2:
    print("Tuesday")
elif a==3:
    print("Wednesday")
elif a==4:
    print("Thursday")
elif a==5:
    print("Friday")
elif a==6:
    print("Saturday")
elif a==7:
    print("Sunday")
else:
    print("Invalid Input..!")
# Out:
# Enter no. :7
# Sunday

# %% [markdown]
# ### 07) WAP to implement simple calculator which performs (add,sub,mul,div) of two no. based on user input.

# %%
a=int(input("Enter no. a:"))
b=int(input("Enter no. b:"))
i=float(input("enter \n 1. Addition \n 2. Substraction \n 3. Multiplication \n 4. Division\n"))
if i==1:
  ans=a+b
  print("Addition answer:",ans)
elif i==2:
  ans=a-b
  print("Substraction answer:",ans)
elif i==3:
  ans=a*b
  print("Multiplication answer:",ans)
elif i==4:
  ans=a/b
  print("Division answer:",ans)
else:
  print("Invalid Input....!!!")
# Out:
# Enter no. a:5
# Enter no. b:5
# enter
#  1. Addition
#  2. Substraction
#  3. Multiplication
#  4. Division
# 1
# Addition answer: 10

# %% [markdown]
# ### 08) WAP to calculate electricity bill based on following criteria. Which takes the unit from the user.
# a. First 1 to 50 units – Rs. 2.60/unit</br>
# b. Next 50 to 100 units – Rs. 3.25/unit</br>
# c. Next 100 to 200 units – Rs. 5.26/unit</br>
# d. above 200 units – Rs. 8.45/unit

# %%
i=float(input("Enter Units:"))
if i>=1 and i<50 :
  ans=i*2.60
  print("Electricity Bill =Rs. ",ans)
elif i>=50 and i<100:
  ans=i*3.25 
  print("Electricity Bill =Rs. ",ans)
elif i>=100 and i<200:
  ans=i*5.26
  print("Electricity Bill =Rs. ",ans)
elif i>=200:
  ans=i*8.45
  print("Electricity Bill =Rs. ",ans)
else:
  print("Invalid input...!!!")
# Out:
# Enter Units:225
# Electricity Bill =Rs.  1901.2499999999998

# %% [markdown]
# ### 01) WAP to read marks of five subjects. Calculate percentage and print class accordingly.
# Fail below 35 </br>
# Pass Class between 35 to 45 </br>
# Second Class</br>
# between 45 to 60</br>
# First Class between 60 to 70</br>
# Distinction if more than 70

# %%
s1=float(input("enter marks of  subject-1 (out of 100):"))
s2=float(input("enter marks of  subject-2 (out of 100):"))
s3=float(input("enter marks of  subject-3 (out of 100):"))
s4=float(input("enter marks of  subject-4 (out of 100):"))
s5=float(input("enter marks of  subject-5 (out of 100):"))1
percentage=(s1+s2+s3+s4+s5)/5
print("percentage %:",percentage)
if percentage<35:
  print("FAIL")
elif percentage>35 and percentage<=45:
  print("PASS");
elif percentage>45 and percentage<=60:
  print("SECOND CLASS")
elif percentage>60 and percentage<=70:
  print("FIRST CLASS")
elif percentage>=70:
  print("DISTINCTION")
else:
  print("Invalid Input...!")
# Out:
# enter marks of  subject-1 (out of 100):100
# enter marks of  subject-2 (out of 100):100
# enter marks of  subject-3 (out of 100):100
# enter marks of  subject-4 (out of 100):100
# enter marks of  subject-5 (out of 100):100
# percentage %: 100.0
# DISTINCTION

# %% [markdown]
# ### 02) WAP to find out the Maximum and Minimum number from given 4 numbers.

# %%
a1=int(input("Enter a1:"))
a2=int(input("Enter a2:"))
a3=int(input("Enter a3:"))
a4=int(input("Enter a4:"))
if a1>a2 and a1>a3 and a1>a4:
  print(a1,"is largest.")
if a2>a1 and a2>a3 and a2>a4:
  print(a2,"is largest.")
if a3>a2 and a3>a1 and a3>a4:
  print(a3,"is largest.")
if a4>a2 and a4>a3 and a4>a1:
  print(a4,"is largest.")
# Out:
# Enter a1:5
# Enter a2:565
# Enter a3:213
# Enter a4:8721321
# 8721321 is largest.

# %% [markdown]
# ### 03) WAP to input an integer number and check the last digit of number is even or odd.

# %%
a=int(input("Enter number:"))
last=a%10
if last%2==0:
  print(last," is even.")
else:
  print(last," is odd.")
# Out:
# Enter number:2
# 2  is even.

# %% [markdown]
# ### 04) WAP to determine the roots of the equation ax2+bx+c=0.

# %%
a=int(input("enter value of a:"))
b=int(input("enter value of b:"))
c=int(input("enter value of c:"))
d=(b*b)-4*a*c
x1=(-b+(d)**0.5)/2*a
x2=(-b-(d)**0.5)/2*a
print("Roots are x1=",x1," and x2= ",x2)
# Out:
# enter value of a:1
# enter value of b:0
# enter value of c:-16
# Roots are x1= 4.0  and x2=  -4.0
